# %%
## Test for audio devices:

import sounddevice as sd
print(sd.query_devices())
# Out:
#     0 Microsoft Sound Mapper - Input, MME (2 in, 0 out)
# >   1 IN (5- UA-25EX), MME (2 in, 0 out)
#     2 Microphone (C922 Pro Stream Web, MME (2 in, 0 out)
#     3 CABLE-A Output (VB-Audio Cable , MME (8 in, 0 out)
#     4 Microphone (Steam Streaming Mic, MME (8 in, 0 out)
#     5 VoiceMeeter Aux Output (VB-Audi, MME (8 in, 0 out)
#     6 Headset Microphone (Oculus Virt, MME (1 in, 0 out)
#     7 Microphone (Voicemod Virtual Au, MME (2 in, 0 out)
#     8 CABLE-B Output (VB-Audio Cable , MME (8 in, 0 out)
#     9 VoiceMeeter Output (VB-Audio Vo, MME (8 in, 0 out)
#    10 Microsoft Sound Mapper - Output, MME (0 in, 2 out)
# <  11 OUT (5- UA-25EX), MME (0 in, 2 out)
#    12 VoiceMeeter Input (VB-Audio Voi, MME (0 in, 8 out)
#    13 Speakers (Steam Streaming Speak, MME (0 in, 8 out)
#    14 VoiceMeeter Aux Input (VB-Audio, MME (0 in, 8 out)
#    15 2369M (NVIDIA High Definition A, MME (0 in, 2 out)
#    16 PL2530H (NVIDIA High Definition, MME (0 in, 2 out)
#    17 CABLE-A Input (VB-Audio Cable A, MME (0 in, 8 out)
#    18 CABLE-B Input (VB-Audio Cable B, MME (0 in, 8 out)
#    19 Speakers (Steam Streaming Micro, MME (0 in, 8 out)
#    20 Panasonic-TV (NVIDIA High Defin, MME (0 in, 2 out)
#    21 Speakers (Realtek(R) Audio), MME (0 in, 8 out)
#    22 Headphones (Oculus Virtual Audi, MME (0 in, 2 out)
#    23 Realtek Digital Output (Realtek, MME (0 in, 2 out)
#    24 Line (Voicemod Virtual Audio De, MME (0 in, 2 out)
#    25 Primary Sound Capture Driver, Windows DirectSound (2 in, 0 out)
#    26 IN (5- UA-25EX), Windows DirectSound (2 in, 0 out)
#    27 Microphone (C922 Pro Stream Webcam), Windows DirectSound (2 in, 0 out)
#    28 CABLE-A Output (VB-Audio Cable A), Windows DirectSound (8 in, 0 out)
#    29 Microphone (Steam Streaming Microphone), Windows DirectSound (8 in, 0 out)
#    30 VoiceMeeter Aux Output (VB-Audio VoiceMeeter AUX VAIO), Windows DirectSound (8 in, 0 out)
#    31 Headset Microphone (Oculus Virtual Audio Device), Windows DirectSound (1 in, 0 out)
#    32 Microphone (Voicemod Virtual Audio Device (WDM)), Windows DirectSound (2 in, 0 out)
#    33 CABLE-B Output (VB-Audio Cable B), Windows DirectSound (8 in, 0 out)
#    34 VoiceMeeter Output (VB-Audio VoiceMeeter VAIO), Windows DirectSound (8 in, 0 out)
#    35 Primary Sound Driver, Windows DirectSound (0 in, 2 out)
#    36 OUT (5- UA-25EX), Windows DirectSound (0 in, 2 out)
#    37 VoiceMeeter Input (VB-Audio VoiceMeeter VAIO), Windows DirectSound (0 in, 8 out)
#    38 Speakers (Steam Streaming Speakers), Windows DirectSound (0 in, 8 out)
#    39 VoiceMeeter Aux Input (VB-Audio VoiceMeeter AUX VAIO), Windows DirectSound (0 in, 8 out)
#    40 2369M (NVIDIA High Definition Audio), Windows DirectSound (0 in, 2 out)
#    41 PL2530H (NVIDIA High Definition Audio), Windows DirectSound (0 in, 2 out)
#    42 CABLE-A Input (VB-Audio Cable A), Windows DirectSound (0 in, 8 out)
#    43 CABLE-B Input (VB-Audio Cable B), Windows DirectSound (0 in, 8 out)
#    44 Speakers (Steam Streaming Microphone), Windows DirectSound (0 in, 8 out)
#    45 Panasonic-TV (NVIDIA High Definition Audio), Windows DirectSound (0 in, 2 out)
#    46 Speakers (Realtek(R) Audio), Windows DirectSound (0 in, 8 out)
#    47 Headphones (Oculus Virtual Audio Device), Windows DirectSound (0 in, 2 out)
#    48 Realtek Digital Output (Realtek(R) Audio), Windows DirectSound (0 in, 2 out)
#    49 Line (Voicemod Virtual Audio Device (WDM)), Windows DirectSound (0 in, 2 out)
#    50 VoiceMeeter Input (VB-Audio VoiceMeeter VAIO), Windows WASAPI (0 in, 2 out)
#    51 Speakers (Steam Streaming Speakers), Windows WASAPI (0 in, 2 out)
#    52 OUT (5- UA-25EX), Windows WASAPI (0 in, 2 out)
#    53 VoiceMeeter Aux Input (VB-Audio VoiceMeeter AUX VAIO), Windows WASAPI (0 in, 2 out)
#    54 2369M (NVIDIA High Definition Audio), Windows WASAPI (0 in, 2 out)
#    55 PL2530H (NVIDIA High Definition Audio), Windows WASAPI (0 in, 2 out)
#    56 CABLE-A Input (VB-Audio Cable A), Windows WASAPI (0 in, 2 out)
#    57 CABLE-B Input (VB-Audio Cable B), Windows WASAPI (0 in, 2 out)
#    58 Speakers (Steam Streaming Microphone), Windows WASAPI (0 in, 2 out)
#    59 Panasonic-TV (NVIDIA High Definition Audio), Windows WASAPI (0 in, 2 out)
#    60 Speakers (Realtek(R) Audio), Windows WASAPI (0 in, 6 out)
#    61 Headphones (Oculus Virtual Audio Device), Windows WASAPI (0 in, 2 out)
#    62 Realtek Digital Output (Realtek(R) Audio), Windows WASAPI (0 in, 2 out)
#    63 Line (Voicemod Virtual Audio Device (WDM)), Windows WASAPI (0 in, 2 out)
#    64 Microphone (C922 Pro Stream Webcam), Windows WASAPI (2 in, 0 out)
#    65 CABLE-A Output (VB-Audio Cable A), Windows WASAPI (2 in, 0 out)
#    66 Microphone (Steam Streaming Microphone), Windows WASAPI (1 in, 0 out)
#    67 VoiceMeeter Aux Output (VB-Audio VoiceMeeter AUX VAIO), Windows WASAPI (2 in, 0 out)
#    68 Headset Microphone (Oculus Virtual Audio Device), Windows WASAPI (1 in, 0 out)
#    69 Microphone (Voicemod Virtual Audio Device (WDM)), Windows WASAPI (2 in, 0 out)
#    70 IN (5- UA-25EX), Windows WASAPI (2 in, 0 out)
#    71 CABLE-B Output (VB-Audio Cable B), Windows WASAPI (2 in, 0 out)
#    72 VoiceMeeter Output (VB-Audio VoiceMeeter VAIO), Windows WASAPI (2 in, 0 out)
#    73 CABLE-B Output (VB-Audio CABLE-B), Windows WDM-KS (8 in, 0 out)
#    74 Speakers (VB-Audio CABLE-B), Windows WDM-KS (0 in, 8 out)
#    75 Speakers (), Windows WDM-KS (0 in, 2 out)
#    76 Microphone (Voicemod VAD Wave), Windows WDM-KS (2 in, 0 out)
#    77 Line Out (Voicemod VAD Wave), Windows WDM-KS (0 in, 2 out)
#    78 Line Out (OUT (UA-25EX)), Windows WDM-KS (0 in, 2 out)
#    79 IN (IN (UA-25EX)), Windows WDM-KS (2 in, 0 out)
#    80 Stereo Mix (Realtek HD Audio Stereo input), Windows WDM-KS (2 in, 0 out)
#    81 Microphone (Realtek HD Audio Mic input), Windows WDM-KS (2 in, 0 out)
#    82 Speakers (Realtek HD Audio output), Windows WDM-KS (0 in, 8 out)
#    83 SPDIF Out (Realtek HDA SPDIF Out), Windows WDM-KS (0 in, 2 out)
#    84 Headphones (Realtek HD Audio 2nd output), Windows WDM-KS (0 in, 2 out)
#    85 VoiceMeeter Aux Output (VoiceMeeter Aux vaio), Windows WDM-KS (8 in, 0 out)
#    86 Speakers (VoiceMeeter Aux vaio), Windows WDM-KS (0 in, 8 out)
#    87 Headset Microphone (OCULUSVAD Wave Microphone Headphone), Windows WDM-KS (1 in, 0 out)
#    88 Output 1 (OCULUSVAD Wave Speaker Headphone), Windows WDM-KS (0 in, 2 out)
#    89 Output 2 (OCULUSVAD Wave Speaker Headphone), Windows WDM-KS (0 in, 2 out)
#    90 Input (OCULUSVAD Wave Speaker Headphone), Windows WDM-KS (2 in, 0 out)
#    91 Output (NVIDIA High Definition Audio), Windows WDM-KS (0 in, 2 out)
#    92 Output (), Windows WDM-KS (0 in, 2 out)
#    93 Output (), Windows WDM-KS (0 in, 2 out)
#    94 Headphones (), Windows WDM-KS (0 in, 2 out)
#    95 Input (), Windows WDM-KS (2 in, 0 out)
#    96 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(LE_WH-XB900N)), Windows WDM-KS (0 in, 1 out)
#    97 Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free%0
# ;(LE_WH-XB900N)), Windows WDM-KS (1 in, 0 out)
#    98 Output (@System32\drivers\bthhfenum.sys,#4;%1 Hands-Free HF Audio%0
# ;(MXYu67)), Windows WDM-KS (0 in, 1 out)
#    99 Input (@System32\drivers\bthhfenum.sys,#4;%1 Hands-Free HF Audio%0
# ;(MXYu67)), Windows WDM-KS (1 in, 0 out)
#   100 Microphone (Steam Streaming Microphone Wave), Windows WDM-KS (8 in, 0 out)
#   101 Speakers (Steam Streaming Microphone Wave), Windows WDM-KS (0 in, 8 out)
#   102 Input (Steam Streaming Speakers Wave), Windows WDM-KS (8 in, 0 out)
#   103 Speakers (Steam Streaming Speakers Wave), Windows WDM-KS (0 in, 8 out)
#   104 VoiceMeeter Output (VoiceMeeter vaio), Windows WDM-KS (8 in, 0 out)
#   105 Speakers (VoiceMeeter vaio), Windows WDM-KS (0 in, 8 out)
#   106 Microphone (C922 Pro Stream Webcam), Windows WDM-KS (2 in, 0 out)
#   107 CABLE-A Output (VB-Audio CABLE-A), Windows WDM-KS (8 in, 0 out)
#   108 Speakers (VB-Audio CABLE-A), Windows WDM-KS (0 in, 8 out)

# %%
import sounddevice as sd
for i, api in enumerate(sd.query_hostapis()):
    print(i, api['name'])
# Out:
# 0 MME
# 1 Windows DirectSound
# 2 Windows WASAPI
# 3 Windows WDM-KS

# %%
import sounddevice as sd

sd.check_input_settings(device=108, samplerate=44100, channels=2)
sd.check_output_settings(device=108, samplerate=44100, channels=2)
# Out:
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 import sounddevice as sd
# ----> 3 sd.check_input_settings(device=108, samplerate=44100, channels=2)
#       4 sd.check_output_settings(device=108, samplerate=44100, channels=2)
#
# File c:\Users\maxmy\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sounddevice.py:693, in check_input_settings(device, channels, dtype, extra_settings, samplerate)
#     669 """Check if given input device settings are supported.
#     670
#     671 All parameters are optional, `default` settings are used for any
#    (...)    688
#     689 """
#     690 parameters, dtype, samplesize, samplerate = _get_stream_parameters(
#     691     'input', device=device, channels=channels, dtype=dtype, latency=None,
#     692     extra_settings=extra_settings, samplerate=samplerate)
# --> 693 _check(_lib.Pa_IsFormatSupported(parameters, _ffi.NULL, samplerate))
#
# File c:\Users\maxmy\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sounddevice.py:2838, in _check(err, msg)
#    2835     hosterror_info = host_api, info.errorCode, hosterror_text
#    2836     raise PortAudioError(errormsg, err, hosterror_info)
# -> 2838 raise PortAudioError(errormsg, err)
#
# PortAudioError: Invalid number of channels [PaErrorCode -9998]

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from IPython.display import clear_output
import time

def create_icosahedron():
    phi = (1 + np.sqrt(5)) / 2  # Golden ratio

    vertices = np.array([
        [-1, phi, 0], [1, phi, 0], [-1, -phi, 0], [1, -phi, 0],
        [0, -1, phi], [0, 1, phi], [0, -1, -phi], [0, 1, -phi],
        [phi, 0, -1], [phi, 0, 1], [-phi, 0, -1], [-phi, 0, 1]
    ])

    # normalise
    vertices /= np.linalg.norm(vertices[0])

    # define the 20 triangular faces
    faces = np.array([
        [0, 11, 5], [0, 5, 1], [0, 1, 7], [0, 7, 10], [0, 10, 11],
        [1, 5, 9], [5, 11, 4], [11, 10, 2], [10, 7, 6], [7, 1, 8],
        [3, 9, 4], [3, 4, 2], [3, 2, 6], [3, 6, 8], [3, 8, 9],
        [4, 9, 5], [2, 4, 11], [6, 2, 10], [8, 6, 7], [9, 8, 1]
    ])

    return vertices, faces

def rotation_matrix(angle, axis):
    axis = axis / np.linalg.norm(axis)
    cos, sin = np.cos(angle), np.sin(angle)
    
    return np.array([
        [cos + axis[0]**2*(1-cos), axis[0]*axis[1]*(1-cos) - axis[2]*sin, axis[0]*axis[2]*(1-cos) + axis[1]*sin],
        [axis[1]*axis[0]*(1-cos) + axis[2]*sin, cos + axis[1]**2*(1-cos), axis[1]*axis[2]*(1-cos) - axis[0]*sin],
        [axis[2]*axis[0]*(1-cos) - axis[1]*sin, axis[2]*axis[1]*(1-cos) + axis[0]*sin, cos + axis[2]**2*(1-cos)]
    ])

# Create figure
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

# Get icosahedron data
vertices, faces = create_icosahedron()

# Animation loop
for angle in np.arange(0, 4*np.pi, 0.1):
    ax.clear()
    
    # Rotate vertices
    R = rotation_matrix(angle, [1, 1, 1])
    rotated_vertices = vertices @ R.T
    
    # Plot edges
    for face in faces:
        # Get vertices of this face (triangular)
        v0, v1, v2 = rotated_vertices[face]
        
        # Plot triangle edges
        ax.plot3D(*zip(v0, v1), 'b-', linewidth=1, alpha=0.8)
        ax.plot3D(*zip(v1, v2), 'b-', linewidth=1, alpha=0.8)
        ax.plot3D(*zip(v2, v0), 'b-', linewidth=1, alpha=0.8)
    
    # Plot vertices
    ax.scatter(*rotated_vertices.T, c='red', s=50)
    
    # Set equal aspect ratio
    ax.set_xlim([-1.5, 1.5])
    ax.set_ylim([-1.5, 1.5])
    ax.set_zlim([-1.5, 1.5])
    
    # Hide axes
    ax.set_axis_off()
    
    # Update display
    clear_output(wait=True)
    display(fig)
    time.sleep(0.01)

plt.close()
